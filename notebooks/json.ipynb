# %%
import pandas as pd

# %%
test = pd.read_parquet("../data/test.parquet")

# %%
dict(test.loc[0, :])
# Out:
# {'user_id': 120738,
#  'adv_campaign_id': 195,
#  'platform_id': 2,
#  'adv_creative_id': 3267,
#  'event_date': Timestamp('2024-09-21 00:00:00'),
#  'banner_code': 8,
#  'is_main': True,
#  'target': 0,
#  'dayofweek': 5,
#  'is_weekend': 1,
#  'end_date': Timestamp('2024-09-27 00:00:00'),
#  'days_to_campaign_end': 6,
#  'is_campaign_early': False,
#  'user_click_rate': 0.01418,
#  'user_impressions_count': 141,
#  'user_campaign_diversity': 67,
#  'campaign_ctr': 0.007122,
#  'campaign_impressions': 13760,
#  'campaign_budget_per_day': 576.5,
#  'logcat_id': 65,
#  'creative_click_rate': 0.007122,
#  'creative_impressions': 13760,
#  'banner_click_rate': 0.005474,
#  'banner_impressions': 74296252,
#  'platform_ctr': 0.006027,
#  'microcat_popularity': 551,
#  'parent_microcat_count': 93,
#  'user_campaign_interaction_rate': 0.0}

# %%
test[test["target"] == 1]
# Out:
#           user_id  adv_campaign_id  platform_id  adv_creative_id event_date  \
# 176       1393763             2632            2             3316 2024-09-21
# 353        722678             1901            2             1454 2024-09-21
# 583       2024613             1856            2             2160 2024-09-21
# 678       1979367             2715            2             2489 2024-09-21
# 736       2014775             3129            3              121 2024-09-21
# ...           ...              ...          ...              ...        ...
# 11473543   610193             1384            2             2693 2024-09-22
# 11473547  2147874               78            2             2709 2024-09-22
# 11473664    55894             1283            2             3587 2024-09-22
# 11473755   678050             2347            2             3016 2024-09-22
# 11474081  2698932             1369            2             2184 2024-09-22
#
# ...

# %%
dict(test.loc[176, :])
# Out:
# {'user_id': 1393763,
#  'adv_campaign_id': 2632,
#  'platform_id': 2,
#  'adv_creative_id': 3316,
#  'event_date': Timestamp('2024-09-21 00:00:00'),
#  'banner_code': 8,
#  'is_main': True,
#  'target': 1,
#  'dayofweek': 5,
#  'is_weekend': 1,
#  'end_date': Timestamp('2024-09-29 00:00:00'),
#  'days_to_campaign_end': 8,
#  'is_campaign_early': False,
#  'user_click_rate': 0.01563,
#  'user_impressions_count': 64,
#  'user_campaign_diversity': 43,
#  'campaign_ctr': 0.005787,
#  'campaign_impressions': 70334,
#  'campaign_budget_per_day': 2662.0,
#  'logcat_id': 18,
#  'creative_click_rate': 0.005787,
#  'creative_impressions': 70334,
#  'banner_click_rate': 0.005474,
#  'banner_impressions': 74296252,
#  'platform_ctr': 0.006027,
#  'microcat_popularity': 6260,
#  'parent_microcat_count': 2364,
#  'user_campaign_interaction_rate': 1.0}
